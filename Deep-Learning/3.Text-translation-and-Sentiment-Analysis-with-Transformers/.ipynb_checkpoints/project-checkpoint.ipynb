# %% [markdown]
# # Text Translation and Sentiment Analysis using Transformers

# %% [markdown]
# ## Project Overview:
#
# The objective of this project is to analyze the sentiment of movie reviews in three different languages - English, French, and Spanish. We have been given 30 movies, 10 in each language, along with their reviews and synopses in separate CSV files named `movie_reviews_eng.csv`, `movie_reviews_fr.csv`, and `movie_reviews_sp.csv`.
#
# - The first step of this project is to convert the French and Spanish reviews and synopses into English. This will allow us to analyze the sentiment of all reviews in the same language. We will be using pre-trained transformers from HuggingFace to achieve this task.
#
# - Once the translations are complete, we will create a single dataframe that contains all the movies along with their reviews, synopses, and year of release in all three languages. This dataframe will be used to perform sentiment analysis on the reviews of each movie.
#
# - Finally, we will use pretrained transformers from HuggingFace to analyze the sentiment of each review. The sentiment analysis results will be added to the dataframe. The final dataframe will have 30 rows
#
#
# The output of the project will be a CSV file with a header row that includes column names such as **Title**, **Year**, **Synopsis**, **Review**, **Review Sentiment**, and **Original Language**. The **Original Language** column will indicate the language of the review and synopsis (*en/fr/sp*) before translation. The dataframe will consist of 30 rows, with each row corresponding to a movie.

# %%
# imports
import pandas as pd
import os
from transformers import MarianMTModel, MarianTokenizer
from transformers import pipeline
# Out:
# 2023-11-19 18:51:42.627139: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-11-19 18:51:42.627175: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Get data from `.csv` files and then preprocess data

# %%
# use the `pd.read_csv()` function to read the movie_review_*.csv files into 3 separate pandas dataframes

# Note: All the dataframes would have different column names. For testing purposes
# you should have the following column names/headers -> [Title, Year, Synopsis, Review]

def rename_columns(df):
    # Rename columns
    new_columns = ["Title", "Year", "Synopsis", "Review"]
    df.columns = new_columns
    return df

def preprocess_data() -> pd.DataFrame:
    """
    Reads movie data from .csv files, map column names, add the "Original Language" column,
    and finally concatenate in one resultant dataframe called "df".
    """

    final_df = pd.DataFrame(columns=["Title", "Year", "Synopsis", "Review", 
                                     'Review Sentiment', 'Original Language'])

    directory = "data"
    csv_files = os.listdir(directory)
    
    # Process each CSV file
    for f in csv_files:
        # Read the CSV file
        file_path = os.path.join(directory, f)
        df = pd.read_csv(file_path)

        # Rename columns
        df = rename_columns(df)
        df['Review Sentiment'] = None
        df['Original Language'] = f.split(".")[0].split("_")[2]

        # Save the final DataFrame
        final_df = pd.concat([final_df, df], ignore_index=True)
        
    return final_df

final_df = preprocess_data()

# %%
final_df.sample(10)
# Out:
#                 Title  Year  \
# 6             Toc Toc  2017
# 21       Intouchables  2011
# 15  Blade Runner 2049  2017
# 0                Roma  2018
# 23      Les Choristes  2004
# 14          Inception  2010
# 13     The Godfather   1972
# 20         La La Land  2016
# 22             Amélie  2001
# 9        El Incidente  2014
#
#                                              Synopsis  \
# 6   En esta comedia española, un grupo de personas...
# 21  Ce film raconte l'histoire de l'amitié improba...
# 15  Officer K (Ryan Gosling), a new blade runner f...
# 0   Cleo (Yalitza Aparicio) es una joven empleada ...
# 23  Ce film raconte l'histoire d'un professeur de ...
# 14  Dom Cobb (Leonardo DiCaprio) is a skilled thie...
# 13  Don Vito Corleone (Marlon Brando) is the head ...
# 20  Cette comédie musicale raconte l'histoire d'un...
# 22  Cette comédie romantique raconte l'histoire d'...
# 9   En esta película de terror mexicana, un grupo ...
#
# ...

# %% [markdown]
# ### Text translation
#
# Translate the **Review** and **Synopsis** column values to English.

# %%
# load translation models and tokenizers
# TODO 2: Update the code below

fr_en_model_name = "Helsinki-NLP/opus-mt-fr-en"
es_en_model_name = "Helsinki-NLP/opus-mt-es-en"

fr_en_model = MarianMTModel.from_pretrained(fr_en_model_name)
es_en_model = MarianMTModel.from_pretrained(es_en_model_name)

fr_en_tokenizer = MarianTokenizer.from_pretrained(fr_en_model_name)
es_en_tokenizer = MarianTokenizer.from_pretrained(es_en_model_name)

# TODO 3: Complete the function below
def translate(text: str, model, tokenizer) -> str:
    """
    function to translate a text using a model and tokenizer
    """
    # encode the text using the tokenizer
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True)

    # generate the translation using the model
    outputs = model.generate(**inputs)

    # decode the generated output and return the translated text
    decoded = [tokenizer.decode(t, skip_special_tokens=True) for t in outputs]
    
    return decoded
# Out:
# /home/natasha/anaconda3/lib/python3.7/site-packages/transformers/models/marian/tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
# TODO 4: Update the code below

# filter reviews in French and translate to English
fr_reviews = final_df[final_df['Original Language'] == 'fr']['Review'].tolist()
fr_reviews_en = translate(fr_reviews, fr_en_model, fr_en_tokenizer)

# filter synopsis in French and translate to English
fr_synopsis = final_df[final_df['Original Language'] == 'fr']['Synopsis'].tolist()
fr_synopsis_en = translate(fr_synopsis, fr_en_model, fr_en_tokenizer)

# filter reviews in Spanish and translate to English
es_reviews = final_df[final_df['Original Language'] == 'sp']['Review'].tolist()
es_reviews_en = translate(es_reviews, es_en_model, es_en_tokenizer)

# filter synopsis in Spanish and translate to English
es_synopsis = final_df[final_df['Original Language'] == 'sp']['Synopsis'].tolist()
es_synopsis_en = translate(es_synopsis, es_en_model, es_en_tokenizer)

# update dataframe with translated text
# add the translated reviews and synopsis - you can overwrite the existing data
# Out:
# /home/natasha/anaconda3/lib/python3.7/site-packages/transformers/generation/utils.py:1392: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 512 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
final_df.loc[final_df['Original Language'] == 'fr', 'Review'] = fr_reviews_en
final_df.loc[final_df['Original Language'] == 'fr', 'Synopsis'] = fr_synopsis_en
final_df.loc[final_df['Original Language'] == 'sp', 'Review'] = es_reviews_en
final_df.loc[final_df['Original Language'] == 'sp', 'Synopsis'] = es_synopsis_en

# %%
final_df.sample(10)
# Out:
#                                  Title         Year  \
# 14                           Inception         2010
# 13                      The Godfather          1972
# 26      La Tour Montparnasse Infernale         2001
# 12                        Forrest Gump         1994
# 15                   Blade Runner 2049         2017
# 11                    The Dark Knight          2008
# 29                        Babylon A.D.         2008
# 1                     La Casa de Papel  (2017-2021)
# 8   Torrente: El brazo tonto de la ley         1998
# 23                       Les Choristes         2004
#
#                                              Synopsis  \
# 14  Dom Cobb (Leonardo DiCaprio) is a skilled thie...
# 13  Don Vito Corleone (Marlon Brando) is the head ...
# 26  Two incompetent office workers find themselves...
# 12  Forrest Gump (Tom Hanks) is a simple man with ...
# 15  Officer K (Ryan Gosling), a new blade runner f...
# 11  Batman (Christian Bale) teams up with District...
# ...

# %% [markdown]
# ### Sentiment Analysis
#
# Use HuggingFace pretrained model for sentiment analysis of the reviews. Store the sentiment result **Positive** or **Negative** in a new column titled **Sentiment** in the dataframe.

# %%
# TODO 5: Update the code below
# load sentiment analysis model
model_name = 'sentiment-analysis'
sentiment_classifier = pipeline(model_name)

# TODO 6: Complete the function below
def analyze_sentiment(text, classifier):
    """
    function to perform sentiment analysis on a text using a model
    """
    results = classifier(text)
    labels = [result['label'].capitalize() for result in results]
    return labels
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
# TODO 7: Add code below for sentiment analysis
# perform sentiment analysis on reviews and store results in new column
#for i in range(len)
sentiment_results = analyze_sentiment(final_df["Review"].tolist(), sentiment_classifier)
final_df["Review Sentiment"] = sentiment_results

# %%
final_df.sample(10)
# Out:
#                                  Title  Year  \
# 13                      The Godfather   1972
# 8   Torrente: El brazo tonto de la ley  1998
# 25                    Le Dîner de Cons  1998
# 21                        Intouchables  2011
# 22                              Amélie  2001
# 11                    The Dark Knight   2008
# 27         Astérix aux Jeux Olympiques  2008
# 10           The Shawshank Redemption   1994
# 4                        Amores perros  2000
# 9                         El Incidente  2014
#
#                                              Synopsis  \
# 13  Don Vito Corleone (Marlon Brando) is the head ...
# 8   In this Spanish comedy, a corrupt cop (played ...
# 25  The film follows the story of a group of rich ...
# 21  This film tells the story of the unlikely frie...
# 22  This romantic comedy tells the story of Amélie...
# 11  Batman (Christian Bale) teams up with District...
# 27  In this film adaptation of the popular comic s...
# ...

# %%
# export the results to a .csv file
final_df.to_csv("result/reviews_with_sentiment.csv", index=False)
