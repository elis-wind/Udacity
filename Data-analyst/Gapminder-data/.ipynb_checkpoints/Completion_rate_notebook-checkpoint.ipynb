# %%
import numpy as np
import pandas as pd

# %%
male_data = pd.read_csv("male_completion_rate.csv")
male_data
# Out:
#                    Country  1970  1971     1972      1973      1974      1975  \
# 0                 Abkhazia   NaN   NaN      NaN       NaN       NaN       NaN
# 1              Afghanistan   NaN   NaN      NaN       NaN  26.23178       NaN
# 2    Akrotiri and Dhekelia   NaN   NaN      NaN       NaN       NaN       NaN
# 3                  Albania   NaN   NaN      NaN       NaN       NaN       NaN
# 4                  Algeria   NaN   NaN  55.3917  57.41252  60.71733  66.29215
# ..                     ...   ...   ...      ...       ...       ...       ...
# 270                Bonaire   NaN   NaN      NaN       NaN       NaN       NaN
# 271                   Sark   NaN   NaN      NaN       NaN       NaN       NaN
# 272         Chinese Taipei   NaN   NaN      NaN       NaN       NaN       NaN
# 273        Saint Eustatius   NaN   NaN      NaN       NaN       NaN       NaN
# 274                   Saba   NaN   NaN      NaN       NaN       NaN       NaN
#
# ...

# %%
female_data = pd.read_csv("female_completion_rate.csv")
female_data
# Out:
#                    Country  1970  1971      1972      1973      1974     1975  \
# 0                 Abkhazia   NaN   NaN       NaN       NaN       NaN      NaN
# 1              Afghanistan   NaN   NaN       NaN       NaN   4.19285      NaN
# 2    Akrotiri and Dhekelia   NaN   NaN       NaN       NaN       NaN      NaN
# 3                  Albania   NaN   NaN       NaN       NaN       NaN      NaN
# 4                  Algeria   NaN   NaN  30.90031  33.02938  34.32702  39.7942
# ..                     ...   ...   ...       ...       ...       ...      ...
# 270                Bonaire   NaN   NaN       NaN       NaN       NaN      NaN
# 271                   Sark   NaN   NaN       NaN       NaN       NaN      NaN
# 272         Chinese Taipei   NaN   NaN       NaN       NaN       NaN      NaN
# 273        Saint Eustatius   NaN   NaN       NaN       NaN       NaN      NaN
# 274                   Saba   NaN   NaN       NaN       NaN       NaN      NaN
#
# ...

# %%
male_data["mean"] = male_data.mean(axis=1)
male_data
# Out:
#                    Country  1970  1971     1972      1973      1974      1975  \
# 0                 Abkhazia   NaN   NaN      NaN       NaN       NaN       NaN
# 1              Afghanistan   NaN   NaN      NaN       NaN  26.23178       NaN
# 2    Akrotiri and Dhekelia   NaN   NaN      NaN       NaN       NaN       NaN
# 3                  Albania   NaN   NaN      NaN       NaN       NaN       NaN
# 4                  Algeria   NaN   NaN  55.3917  57.41252  60.71733  66.29215
# ..                     ...   ...   ...      ...       ...       ...       ...
# 270                Bonaire   NaN   NaN      NaN       NaN       NaN       NaN
# 271                   Sark   NaN   NaN      NaN       NaN       NaN       NaN
# 272         Chinese Taipei   NaN   NaN      NaN       NaN       NaN       NaN
# 273        Saint Eustatius   NaN   NaN      NaN       NaN       NaN       NaN
# 274                   Saba   NaN   NaN      NaN       NaN       NaN       NaN
#
# ...

# %%
female_data["mean"] = female_data.mean(axis=1)
female_data
# Out:
#                    Country  1970  1971      1972      1973      1974     1975  \
# 0                 Abkhazia   NaN   NaN       NaN       NaN       NaN      NaN
# 1              Afghanistan   NaN   NaN       NaN       NaN   4.19285      NaN
# 2    Akrotiri and Dhekelia   NaN   NaN       NaN       NaN       NaN      NaN
# 3                  Albania   NaN   NaN       NaN       NaN       NaN      NaN
# 4                  Algeria   NaN   NaN  30.90031  33.02938  34.32702  39.7942
# ..                     ...   ...   ...       ...       ...       ...      ...
# 270                Bonaire   NaN   NaN       NaN       NaN       NaN      NaN
# 271                   Sark   NaN   NaN       NaN       NaN       NaN      NaN
# 272         Chinese Taipei   NaN   NaN       NaN       NaN       NaN      NaN
# 273        Saint Eustatius   NaN   NaN       NaN       NaN       NaN      NaN
# 274                   Saba   NaN   NaN       NaN       NaN       NaN      NaN
#
# ...

# %%
def overall_completion_rate(female_completion, male_completion):
    '''
    Fill in this function to return a NumPy array containing the overall
    school completion rate for each country. 
    '''
    overall_data = pd.DataFrame()
    overall_data["country"] = male_completion["Country"]
    overall_data["mean"] = (male_completion["mean"] + female_completion["mean"]) / 2.
    
    return overall_data[["country","mean"]]

# %%
overall_completion_rate(female_data, male_data)
# Out:
#                    country       mean
# 0                 Abkhazia        NaN
# 1              Afghanistan  20.991308
# 2    Akrotiri and Dhekelia        NaN
# 3                  Albania  95.464545
# 4                  Algeria  77.919422
# ..                     ...        ...
# 270                Bonaire        NaN
# 271                   Sark        NaN
# 272         Chinese Taipei        NaN
# 273        Saint Eustatius        NaN
# 274                   Saba        NaN
#
# [275 rows x 2 columns]
